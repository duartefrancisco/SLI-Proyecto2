# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import helpers.Utilidades as utilidades

# %%
dataset = pd.read_csv("./data/dataset.csv")

# %% [markdown]
# # Análsis

# %% [markdown]
# ## Exploración

# %%
dataset
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2661        10350               20     100.00               15  2244.40
# 2662        10373               29     100.00                1  3978.51
# 2663        10386               43     100.00                4  5417.57
# 2664        10397               34      62.24                1  2116.16
# 2665        10414               47      65.52                9  3079.44
#
#              ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
dataset.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
dataset.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %%
y = "DEALSIZE"

# %%
dataset[y].value_counts()
# Out:
# Medium    1384
# Small     1282
# Name: DEALSIZE, dtype: int64

# %% [markdown]
# ### Obtemos tipos de columnas

# %%
columnasNumericasDiscretas, columnasNumericasContinuas, columnasCategoricas, columnasFecha = utilidades.ObtenerTiposColumnas(dataset)

# %%
columnasNumericasDiscretas
# Out:
# ['ORDERLINENUMBER', 'QTR_ID', 'MONTH_ID', 'YEAR_ID']

# %%
columnasNumericasContinuas
# Out:
# ['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'SALES', 'MSRP']

# %%
columnasFecha
# Out:
# []

# %%
columnasCategoricas
# Out:
# ['ORDERDATE',
#  'STATUS',
#  'PRODUCTLINE',
#  'PRODUCTCODE',
#  'CUSTOMERNAME',
#  'PHONE',
#  'ADDRESSLINE1',
#  'ADDRESSLINE2',
#  'CITY',
#  'STATE',
#  'POSTALCODE',
#  'COUNTRY',
#  'TERRITORY',
#  'CONTACTLASTNAME',
#  'CONTACTFIRSTNAME',
#  'DEALSIZE']

# %% [markdown]
# ## Gráficas

# %%
utilidades.GraficaVariablesCategoricas(dataset,columnasCategoricas, y)

# %%
dataset["PRODUCTCODE"].unique()
# Out:
# array(['S10_1678', 'S10_1949', 'S10_2016', 'S10_4698', 'S10_4757',
#        'S10_4962', 'S12_1099', 'S12_1108', 'S12_1666', 'S12_2823',
#        'S12_3148', 'S12_3380', 'S12_3891', 'S12_3990', 'S12_4473',
#        'S12_4675', 'S18_1097', 'S18_1129', 'S18_1342', 'S18_1367',
#        'S18_1589', 'S18_1662', 'S18_1749', 'S18_1889', 'S18_1984',
#        'S18_2238', 'S18_2248', 'S18_2319', 'S18_2325', 'S18_2432',
#        'S18_2581', 'S18_2625', 'S18_2795', 'S18_2870', 'S18_2949',
#        'S18_2957', 'S18_3029', 'S18_3136', 'S18_3140', 'S18_3232',
#        'S18_3259', 'S18_3278', 'S18_3320', 'S18_3482', 'S18_3685',
#        'S18_3782', 'S18_3856', 'S18_4027', 'S18_4409', 'S18_4522',
#        'S18_4600', 'S18_4668', 'S18_4721', 'S18_4933', 'S24_1046',
#        'S24_1444', 'S24_1578', 'S24_1628', 'S24_1785', 'S24_1937',
#        'S24_2000', 'S24_2011', 'S24_2022', 'S24_2300', 'S24_2360',
#        'S24_2766', 'S24_2840', 'S24_2841', 'S24_2887', 'S24_2972',
# ...

# %%
len(dataset["PRODUCTCODE"].unique())
# Out:
# 109

# %%
dataset["CUSTOMERNAME"].unique()
# Out:
# array(['Land of Toys Inc.', 'Reims Collectables', 'Lyon Souveniers',
#        'Toys4GrownUps.com', 'Corporate Gift Ideas Co.',
#        'Technics Stores Inc.', 'Daedalus Designs Imports', 'Herkku Gifts',
#        'Mini Wheels Co.', 'Auto Canal Petit',
#        'Australian Collectors, Co.', 'Vitachrome Inc.',
#        'Tekni Collectables Inc.', 'Gift Depot Inc.', 'La Rochelle Gifts',
#        "Marta's Replicas Co.", 'Toys of Finland, Co.',
#        'Baane Mini Imports', 'Diecast Classics Inc.',
#        'Souveniers And Things Co.', 'FunGiftIdeas.com',
#        'UK Collectables, Ltd.', 'Classic Legends Inc.',
#        'Classic Gift Ideas, Inc', 'West Coast Collectables Co.',
#        'Cambridge Collectables Co.', 'Super Scale Inc.',
#        'Online Diecast Creations Co.', 'Mini Gifts Distributors Ltd.',
#        'Collectables For Less Inc.', "Anna's Decorations, Ltd",
#        'Quebec Home Shopping Network', 'Osaka Souveniers Co.',
# ...

# %%
len(dataset["CUSTOMERNAME"].unique())
# Out:
# 92

# %%
dataset["PHONE"].unique()
# Out:
# array(['2125557818', '26.47.1555', '+33 1 46 62 7555', '6265557265',
#        '6505551386', '6505556809', '20.16.1555', '+47 2267 3215',
#        '6505555787', '(1) 47.55.6555', '03 9520 4555', '2125551500',
#        '2015559350', '2035552570', '40.67.8555', '6175558555',
#        '90-224 8555', '07-98 9555', '2155551555', '+61 2 9495 8555',
#        '5085552555', '(171) 555-2282', '2125558493', '2155554695',
#        '3105553722', '6175555555', '2035559545', '6035558647',
#        '4155551450', '02 9936 8555', '(514) 555-8054', '+81 06 6342 5555',
#        '2155559857', '40.32.2555', '9145554562', '+81 3 3584 0555',
#        '61-7-3844-6555', '(91) 555 94 44', '6562-9555', '(171) 555-0297',
#        '5085559555', '0695-34 6555', '61.77.6555', '(171) 555-7555',
#        '(93) 203 4555', '2155554369', '7605558146', '(02) 5554 67',
#        '(604) 555-4555', '6175559555', '(198) 555-8888', '981-443655',
#        '(1) 42.34.2555', '(91) 555 22 82', '+65 221 7555', '7675-3555',
# ...

# %%
len(dataset["PHONE"].unique())
# Out:
# 91

# %%
len(dataset["ADDRESSLINE1"].unique())
# Out:
# 92

# %%
len(dataset["CITY"].unique())
# Out:
# 73

# %%
len(dataset["POSTALCODE"].unique())
# Out:
# 74

# %%
len(dataset["COUNTRY"].unique())
# Out:
# 19

# %%
len(dataset["CONTACTFIRSTNAME"].unique())
# Out:
# 72

# %%
len(dataset["CONTACTLASTNAME"].unique())
# Out:
# 77

# %%
dataset[columnasCategoricas].isnull().mean()
# Out:
# ORDERDATE           0.000000
# STATUS              0.000000
# PRODUCTLINE         0.000000
# PRODUCTCODE         0.000000
# CUSTOMERNAME        0.000000
# PHONE               0.000000
# ADDRESSLINE1        0.000000
# ADDRESSLINE2        0.893473
# CITY                0.000000
# STATE               0.526632
# POSTALCODE          0.026632
# COUNTRY             0.000000
# TERRITORY           0.378470
# CONTACTLASTNAME     0.000000
# CONTACTFIRSTNAME    0.000000
# DEALSIZE            0.000000
# dtype: float64

# %%
utilidades.GraficoBarrasCategoricas(dataset, "STATE")

# %%
utilidades.GraficoBarrasCategoricas(dataset, "CITY")

# %%
utilidades.GraficoBarrasCategoricas(dataset, "COUNTRY")

# %%
utilidades.GraficoBarrasCategoricas(dataset, "TERRITORY")

# %% [markdown]
# ## Columnas Númericas

# %% [markdown]
# ### Discretas

# %%
dataset[columnasNumericasDiscretas].isnull().mean()
# Out:
# ORDERLINENUMBER    0.0
# QTR_ID             0.0
# MONTH_ID           0.0
# YEAR_ID            0.0
# dtype: float64

# %%
for columna in columnasNumericasDiscretas:
    utilidades.GraficacaDensidadVariable(dataset, columna)

# %%
for columna in columnasNumericasDiscretas:
    utilidades.GraficosOutliers(dataset, columna)
# Out:
# /Users/francisco/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/francisco/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ### Continuas

# %%
dataset[columnasNumericasContinuas].isnull().mean()
# Out:
# ORDERNUMBER        0.0
# QUANTITYORDERED    0.0
# PRICEEACH          0.0
# SALES              0.0
# MSRP               0.0
# dtype: float64

# %%
for columna in columnasNumericasContinuas:
    utilidades.GraficacaDensidadVariable(dataset, columna)

# %%
for columna in columnasNumericasContinuas:
    utilidades.GraficosOutliers(dataset, columna)
# Out:
# /Users/francisco/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/francisco/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ## Columnas con NA

# %%
columnasConNa = utilidades.ObtenerColumnasConNan(dataset)
columnasConNa
# Out:
# ['ADDRESSLINE2', 'STATE', 'POSTALCODE', 'TERRITORY']

# %%
dataset["TERRITORY"].value_counts()
# Out:
# EMEA     1330
# APAC      213
# Japan     114
# Name: TERRITORY, dtype: int64

# %%
dataset["TERRITORY"].isna().sum()
# Out:
# 1009

# %%
dataset["ADDRESSLINE2"].value_counts()
# Out:
# Level 3        53
# Level 6        45
# Level 15       44
# Suite 400      43
# 2nd Floor      35
# Suite 101      22
# Suite 750      19
# Floor No. 4    14
# Suite 200       9
# Name: ADDRESSLINE2, dtype: int64

# %%
dataset["ADDRESSLINE2"].isna().sum()
# Out:
# 2382

# %%
dataset["STATE"].value_counts()
# Out:
# CA               389
# MA               182
# NY               166
# NSW               89
# Victoria          75
# PA                69
# CT                56
# BC                47
# NH                32
# Tokyo             29
# NV                29
# Isle of Wight     26
# Quebec            22
# Osaka             20
# NJ                17
# Queensland        14
# Name: STATE, dtype: int64

# %%
dataset["STATE"].isna().sum()
# Out:
# 1404

# %%
dataset["POSTALCODE"].value_counts()
# Out:
# 28034      248
# 97562      191
# 10022      141
# 94217       81
# 44000       59
#           ...
# 4101        14
# 80686       14
# WA1 1DP     12
# B-6000       8
# 92561        3
# Name: POSTALCODE, Length: 73, dtype: int64

# %%
dataset["POSTALCODE"].isna().sum()
# Out:
# 71

# %%
dataset[columnasConNa].isnull().mean()
# Out:
# ADDRESSLINE2    0.893473
# STATE           0.526632
# POSTALCODE      0.026632
# TERRITORY       0.378470
# dtype: float64

# %% [markdown]
# # Conclusión

# %% [markdown]
# Tras analizar las gráficas y los distintos resutlados de las variables. Se puede concluir que las siguientes columnas pueden ser eliminadas:
# - ORDERNUMBER
# - ORDERLINENUMBER
# - ORDERDATE (porque ya se cuentra en columnas)
# - TERRITORY (por la cantidad de na)
# - ADDRESSLINE2 (por la cantidad de na)
# - STATE (por la cantidad de na)
